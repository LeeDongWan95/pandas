# %% [markdown]
# <a href="https://colab.research.google.com/github/LeeDongWan95/pandas/blob/main/05_NaN.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ### [참고] <a href="https://pandas.pydata.org/Pandas_Cheat_Sheet.pdf">Pandas Cheat Sheet</a>
#
# https://pandas.pydata.org/docs/user_guide/missing_data.html

# %% [markdown]
# #### NaN(Not a Number) - 표현 불가능한 데이터(비어 있는 값)
#
# - NaN : missing value 를 표현하는 기본 형태
# - 기본적으로 float 형식으로 처리됨
#
# #### NA(Not Available) : 결측값
# #### None : 값의 부재(값이 존재하지 않거나, 없음, 정의되지 않음)

# %%
import pandas as pd
import numpy as np

# %% [markdown]
# ### [실습 1]

# %% [markdown]
# #### 1) missing data 가 포함된 데이터 프레임 생성

# %%
df = pd.DataFrame(
    {
        "name":["Alfred","Batman","Catwoman"],
        "toy":[np.nan,"Batmobile","Bullwhip"],
        "born":[None,pd.Timestamp("19500425"), pd.NA]
    }
)
df
# Out:
#        name        toy                 born
# 0    Alfred        NaN                 None
# 1    Batman  Batmobile  1950-04-25 00:00:00
# 2  Catwoman   Bullwhip                 <NA>

# %% [markdown]
# #### 2) 데이터 타입 확인

# %%
df.dtypes
# Out:
# name    object
# toy     object
# born    object
# dtype: object

# %% [markdown]
# #### 3) missing data 처리

# %% [markdown]
# **dropna : missing values 제거**

# %%
df.dropna?

# %% [markdown]
# df.dropna(axis=0, how='any', thresh=None, subset=None, inplace=False)

# %%
# how=any 행 or 열에 하나라도 널 값이 있으면 없애기
# axis = 0(행), 1(열)

df.dropna(axis=1)
# Out:
#        name
# 0    Alfred
# 1    Batman
# 2  Catwoman

# %%
# how=any 행 or 열에 하나라도 널 값이 있으면 없애기
# axis = 0(행), 1(열)

df.dropna()
# Out:
#      name        toy                 born
# 1  Batman  Batmobile  1950-04-25 00:00:00

# %%
# how='all' 전체 행에 결측치가 모두 있어야 drop

df.dropna(how='all')
# Out:
#        name        toy                 born
# 0    Alfred        NaN                 None
# 1    Batman  Batmobile  1950-04-25 00:00:00
# 2  Catwoman   Bullwhip                 <NA>

# %% [markdown]
# **fillna : missing values 를 임의의 값으로 채우기**

# %%
df.fillna?

# %% [markdown]
# df.fillna(
#     value=None,
#     method=None,
#     axis=None,
#     inplace=False,
#     limit=None,
#     downcast=None,
# )

# %%
# 결측치를 무엇으로 채울 것인가?

df.fillna(0)
# Out:
#        name        toy                 born
# 0    Alfred          0                    0
# 1    Batman  Batmobile  1950-04-25 00:00:00
# 2  Catwoman   Bullwhip                    0

# %%
# 특정 값으로 채우기 - 값이 NaN, NaT, NA, None인 경우에만 채워짐

values = {"name":"noname", "toy":"Bat","born":pd.Timestamp("19000101")}

# %%
df.fillna(value=values)
# Out:
#        name        toy       born
# 0    Alfred        Bat 1900-01-01
# 1    Batman  Batmobile 1950-04-25
# 2  Catwoman   Bullwhip 1900-01-01

# %% [markdown]
# ### [실습 2]

# %%
student_list = {
    "name":
    ["John", "Nate", "Yuna", "Abraham", "Brian", "Janny", "Nate", "John"],
    "job": [
        "teacher", "teacher", "teacher", "student", "student", "student",
        "teacher", "student"
    ],
    "age": [40, 35, 37, 10, 12, 11, None, None]
}
df = pd.DataFrame(student_list)
df
# Out:
#       name      job   age
# 0     John  teacher  40.0
# 1     Nate  teacher  35.0
# 2     Yuna  teacher  37.0
# 3  Abraham  student  10.0
# 4    Brian  student  12.0
# 5    Janny  student  11.0
# 6     Nate  teacher   NaN
# 7     John  student   NaN

# %%
# 전체 행의 개수와 컬럼 개수 확인하기

df.shape
# Out:
# (8, 3)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 8 entries, 0 to 7
# Data columns (total 3 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   name    8 non-null      object
#  1   job     8 non-null      object
#  2   age     6 non-null      float64
# dtypes: float64(1), object(2)
# memory usage: 320.0+ bytes

# %%
df.isnull()
# Out:
#     name    job    age
# 0  False  False  False
# 1  False  False  False
# 2  False  False  False
# 3  False  False  False
# 4  False  False  False
# 5  False  False  False
# 6  False  False   True
# 7  False  False   True

# %%
df.isna()
# Out:
#     name    job    age
# 0  False  False  False
# 1  False  False  False
# 2  False  False  False
# 3  False  False  False
# 4  False  False  False
# 5  False  False  False
# 6  False  False   True
# 7  False  False   True

# %%
# 0 으로 채우기

df.age = df.age.fillna(0)
df
# Out:
#       name      job   age
# 0     John  teacher  40.0
# 1     Nate  teacher  35.0
# 2     Yuna  teacher  37.0
# 3  Abraham  student  10.0
# 4    Brian  student  12.0
# 5    Janny  student  11.0
# 6     Nate  teacher   0.0
# 7     John  student   0.0

# %%
# 평균 값으로 채우기

df.groupby('job')['age'].transform("median")
# Out:
# 0    37.0
# 1    37.0
# 2    37.0
# 3    11.0
# 4    11.0
# 5    11.0
# 6    37.0
# 7    11.0
# Name: age, dtype: float64

# %%
df['age'].fillna(df.groupby('job')['age'].transform("median"), inplace=True)
df
# Out:
#       name      job   age
# 0     John  teacher  40.0
# 1     Nate  teacher  35.0
# 2     Yuna  teacher  37.0
# 3  Abraham  student  10.0
# 4    Brian  student  12.0
# 5    Janny  student  11.0
# 6     Nate  teacher  37.0
# 7     John  student  11.0

# %% [markdown]
# ### 학생 실습

# %%
df = pd.DataFrame(
    [
        [np.nan, 2, np.nan, 0],
        [3,4,np.nan,1],
        [np.nan,np.nan,np.nan,5],
    ], columns=list('ABCD')

  )
df
# Out:
#      A    B   C  D
# 0  NaN  2.0 NaN  0
# 1  3.0  4.0 NaN  1
# 2  NaN  NaN NaN  5

# %%
# 결측치 확인

# df.isna()
df.isnull()
# Out:
#        A      B     C      D
# 0   True  False  True  False
# 1  False  False  True  False
# 2   True   True  True  False

# %%
# 모든 결측치 0 으로 채우기
df.fillna(0)
# Out:
#      A    B    C  D
# 0  0.0  2.0  0.0  0
# 1  3.0  4.0  0.0  1
# 2  0.0  0.0  0.0  5

# %%
# 모든 결측치 특정 값으로 채우기
# A : 0, B : 1, C : 2, D : 3

values = {"A":0,"B":1,"C":2,"D":3}
df.fillna(values)
# Out:
#      A    B    C  D
# 0  0.0  2.0  2.0  0
# 1  3.0  4.0  2.0  1
# 2  0.0  1.0  2.0  5

# %%
# 모든 결측치 D열의 중간값으로 채우기

df.fillna(df['D'].median())
# Out:
#      A    B    C  D
# 0  0.0  2.0  2.0  0
# 1  3.0  4.0  2.0  1
# 2  0.0  1.0  2.0  5

# %%
# 모든 결측치 D열의 최대값으로 채우기

df.fillna(df['D'].max())
# Out:
#      A    B    C  D
# 0  0.0  2.0  2.0  0
# 1  3.0  4.0  2.0  1
# 2  0.0  1.0  2.0  5

# %% [markdown]
# ### [개념] NaN

# %% [markdown]
# d- NaN 을 나타내는 방법으로 np.nan, pd.NaT, pd.NA, None 등이 있음
# - 단, np.nan 은 개별 값으로 비교 시 비교가 안됨
# - None 는 비교가 됨

# %%
print("np.nan != np.nan", np.nan != np.nan)
print("np.nan == np.nan", np.nan == np.nan)
print("pd.NaT == pd.NaT", pd.NaT == pd.NaT)
print("pd.NA == pd.NA", pd.NA == pd.NA)
print("None == None", None == None)
# Out:
# np.nan != np.nan True
# np.nan == np.nan False
# pd.NaT == pd.NaT False
# pd.NA == pd.NA <NA>
# None == None True

# %% [markdown]
# - 표현할 수 없는 값들을 서로 비교를 하기 원한다면 None 로 처리하는 것이 편함
